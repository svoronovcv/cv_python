# %%
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.919663
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.524736
# Minibatch accuracy: 68.8%
# Validation accuracy: 48.1%
# Minibatch loss at step 100: 1.276988
# Minibatch accuracy: 56.2%
# Validation accuracy: 58.0%
# Minibatch loss at step 150: 1.006828
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.1%
# Minibatch loss at step 200: 0.821410
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.4%
# Minibatch loss at step 250: 0.479205
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.7%
# Minibatch loss at step 300: 0.761659
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.4%
# Minibatch loss at step 350: 0.967567
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.9%
# Minibatch loss at step 400: 0.420573
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.5%
# Minibatch loss at step 450: 0.809177
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.6%
# Minibatch loss at step 500: 0.273972
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.1%
# Minibatch loss at step 550: 0.639273
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 600: 0.869523
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.6%
# Minibatch loss at step 650: 0.616897
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 700: 0.138201
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.9%
# Minibatch loss at step 750: 0.921798
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.3%
# Minibatch loss at step 800: 0.456439
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.1%
# Minibatch loss at step 850: 0.410978
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.3%
# Minibatch loss at step 900: 0.456153
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.1%
# Minibatch loss at step 950: 1.253158
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.9%
# Minibatch loss at step 1000: 0.529022
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Test accuracy: 88.3%

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.max_pool(data, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.632429
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.275155
# Minibatch accuracy: 12.5%
# Validation accuracy: 16.2%
# Minibatch loss at step 100: 2.217342
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.1%
# Minibatch loss at step 150: 2.119735
# Minibatch accuracy: 25.0%
# Validation accuracy: 15.5%
# Minibatch loss at step 200: 2.222164
# Minibatch accuracy: 18.8%
# Validation accuracy: 18.4%
# Minibatch loss at step 250: 2.248015
# Minibatch accuracy: 0.0%
# Validation accuracy: 13.5%
# Minibatch loss at step 300: 2.228907
# Minibatch accuracy: 12.5%
# Validation accuracy: 18.9%
# Minibatch loss at step 350: 2.406684
# Minibatch accuracy: 6.2%
# Validation accuracy: 12.5%
# Minibatch loss at step 400: 1.915599
# Minibatch accuracy: 6.2%
# Validation accuracy: 24.5%
# Minibatch loss at step 450: 1.836460
# Minibatch accuracy: 25.0%
# Validation accuracy: 29.1%
# Minibatch loss at step 500: 1.849116
# Minibatch accuracy: 43.8%
# Validation accuracy: 31.2%
# Minibatch loss at step 550: 1.663748
# Minibatch accuracy: 56.2%
# Validation accuracy: 30.6%
# Minibatch loss at step 600: 1.790430
# Minibatch accuracy: 31.2%
# Validation accuracy: 52.1%
# Minibatch loss at step 650: 1.429874
# Minibatch accuracy: 43.8%
# Validation accuracy: 54.1%
# Minibatch loss at step 700: 1.707373
# Minibatch accuracy: 31.2%
# Validation accuracy: 51.7%
# Minibatch loss at step 750: 1.601657
# Minibatch accuracy: 37.5%
# Validation accuracy: 59.1%
# Minibatch loss at step 800: 0.929919
# Minibatch accuracy: 75.0%
# Validation accuracy: 68.6%
# Minibatch loss at step 850: 0.654747
# Minibatch accuracy: 87.5%
# Validation accuracy: 69.6%
# Minibatch loss at step 900: 1.278162
# Minibatch accuracy: 50.0%
# Validation accuracy: 62.1%
# Minibatch loss at step 950: 1.517801
# Minibatch accuracy: 37.5%
# Validation accuracy: 64.2%
# Minibatch loss at step 1000: 1.178636
# Minibatch accuracy: 56.2%
# Validation accuracy: 70.7%
# Test accuracy: 77.2%

# %%
num_steps = 2001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.386856
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.282510
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 100: 2.242128
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 150: 2.262967
# Minibatch accuracy: 18.8%
# Validation accuracy: 15.6%
# Minibatch loss at step 200: 2.248904
# Minibatch accuracy: 12.5%
# Validation accuracy: 16.3%
# Minibatch loss at step 250: 2.126252
# Minibatch accuracy: 12.5%
# Validation accuracy: 14.1%
# Minibatch loss at step 300: 2.170460
# Minibatch accuracy: 6.2%
# Validation accuracy: 16.8%
# Minibatch loss at step 350: 1.999774
# Minibatch accuracy: 31.2%
# Validation accuracy: 19.9%
# Minibatch loss at step 400: 2.048029
# Minibatch accuracy: 0.0%
# Validation accuracy: 21.7%
# Minibatch loss at step 450: 2.019474
# Minibatch accuracy: 37.5%
# Validation accuracy: 22.3%
# Minibatch loss at step 500: 1.920087
# Minibatch accuracy: 25.0%
# Validation accuracy: 35.7%
# Minibatch loss at step 550: 1.869459
# Minibatch accuracy: 37.5%
# Validation accuracy: 35.8%
# Minibatch loss at step 600: 1.703136
# Minibatch accuracy: 25.0%
# Validation accuracy: 47.2%
# Minibatch loss at step 650: 1.822332
# Minibatch accuracy: 18.8%
# Validation accuracy: 43.2%
# Minibatch loss at step 700: 2.374983
# Minibatch accuracy: 25.0%
# Validation accuracy: 26.0%
# Minibatch loss at step 750: 1.804252
# Minibatch accuracy: 31.2%
# Validation accuracy: 46.6%
# Minibatch loss at step 800: 1.749048
# Minibatch accuracy: 37.5%
# Validation accuracy: 35.4%
# Minibatch loss at step 850: 0.884820
# Minibatch accuracy: 81.2%
# Validation accuracy: 55.6%
# Minibatch loss at step 900: 1.281616
# Minibatch accuracy: 56.2%
# Validation accuracy: 52.6%
# Minibatch loss at step 950: 1.629927
# Minibatch accuracy: 37.5%
# Validation accuracy: 53.7%
# Minibatch loss at step 1000: 1.250116
# Minibatch accuracy: 31.2%
# Validation accuracy: 63.5%
# Minibatch loss at step 1050: 1.186574
# Minibatch accuracy: 68.8%
# Validation accuracy: 66.7%
# Minibatch loss at step 1100: 0.801841
# Minibatch accuracy: 75.0%
# Validation accuracy: 64.0%
# Minibatch loss at step 1150: 0.620521
# Minibatch accuracy: 81.2%
# Validation accuracy: 70.8%
# Minibatch loss at step 1200: 1.533179
# Minibatch accuracy: 56.2%
# Validation accuracy: 70.8%
# Minibatch loss at step 1250: 0.768995
# Minibatch accuracy: 68.8%
# Validation accuracy: 72.7%
# Minibatch loss at step 1300: 0.588319
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.1%
# Minibatch loss at step 1350: 0.682814
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.3%
# Minibatch loss at step 1400: 0.671463
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.2%
# Minibatch loss at step 1450: 1.400635
# Minibatch accuracy: 62.5%
# Validation accuracy: 74.6%
# Minibatch loss at step 1500: 0.714904
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.8%
# Minibatch loss at step 1550: 0.964907
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.3%
# Minibatch loss at step 1600: 1.217072
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.5%
# Minibatch loss at step 1650: 0.962248
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.8%
# Minibatch loss at step 1700: 0.769145
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.2%
# Minibatch loss at step 1750: 0.872557
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.0%
# Minibatch loss at step 1800: 0.749810
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.8%
# Minibatch loss at step 1850: 1.128940
# Minibatch accuracy: 56.2%
# Validation accuracy: 74.4%
# Minibatch loss at step 1900: 1.200193
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.6%
# Minibatch loss at step 1950: 1.115137
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.8%
# Minibatch loss at step 2000: 0.212902
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.0%
# Test accuracy: 84.4%

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.avg_pool(data, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.avg_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.227687
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.351949
# Minibatch accuracy: 0.0%
# Validation accuracy: 13.8%
# Minibatch loss at step 100: 2.315803
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.1%
# Minibatch loss at step 150: 2.301715
# Minibatch accuracy: 6.2%
# Validation accuracy: 14.2%
# Minibatch loss at step 200: 2.171808
# Minibatch accuracy: 25.0%
# Validation accuracy: 17.0%
# Minibatch loss at step 250: 2.474051
# Minibatch accuracy: 0.0%
# Validation accuracy: 15.5%
# Minibatch loss at step 300: 2.276537
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 350: 2.314695
# Minibatch accuracy: 25.0%
# Validation accuracy: 14.5%
# Minibatch loss at step 400: 1.974149
# Minibatch accuracy: 31.2%
# Validation accuracy: 23.2%
# Minibatch loss at step 450: 1.923663
# Minibatch accuracy: 31.2%
# Validation accuracy: 27.2%
# Minibatch loss at step 500: 1.954007
# Minibatch accuracy: 25.0%
# Validation accuracy: 33.1%
# Minibatch loss at step 550: 1.797966
# Minibatch accuracy: 31.2%
# Validation accuracy: 33.9%
# Minibatch loss at step 600: 1.754658
# Minibatch accuracy: 43.8%
# Validation accuracy: 46.5%
# Minibatch loss at step 650: 1.436568
# Minibatch accuracy: 50.0%
# Validation accuracy: 48.6%
# Minibatch loss at step 700: 1.403381
# Minibatch accuracy: 37.5%
# Validation accuracy: 43.0%
# Minibatch loss at step 750: 1.387349
# Minibatch accuracy: 56.2%
# Validation accuracy: 53.8%
# Minibatch loss at step 800: 1.093146
# Minibatch accuracy: 68.8%
# Validation accuracy: 61.8%
# Minibatch loss at step 850: 0.529014
# Minibatch accuracy: 87.5%
# Validation accuracy: 73.4%
# Minibatch loss at step 900: 0.610205
# Minibatch accuracy: 75.0%
# Validation accuracy: 72.4%
# Minibatch loss at step 950: 1.462326
# Minibatch accuracy: 56.2%
# Validation accuracy: 66.5%
# Minibatch loss at step 1000: 0.991842
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.5%
# Test accuracy: 83.3%

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.avg_pool(data, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.avg_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

num_steps = 2001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 100 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.729617
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 100: 2.206716
# Minibatch accuracy: 6.2%
# Validation accuracy: 14.6%
# Minibatch loss at step 200: 2.143627
# Minibatch accuracy: 25.0%
# Validation accuracy: 20.9%
# Minibatch loss at step 300: 2.043620
# Minibatch accuracy: 18.8%
# Validation accuracy: 24.7%
# Minibatch loss at step 400: 1.670749
# Minibatch accuracy: 25.0%
# Validation accuracy: 34.6%
# Minibatch loss at step 500: 1.194701
# Minibatch accuracy: 56.2%
# Validation accuracy: 58.9%
# Minibatch loss at step 600: 1.439794
# Minibatch accuracy: 50.0%
# Validation accuracy: 64.7%
# Minibatch loss at step 700: 0.691755
# Minibatch accuracy: 81.2%
# Validation accuracy: 70.7%
# Minibatch loss at step 800: 0.715049
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.4%
# Minibatch loss at step 900: 0.669475
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.8%
# Minibatch loss at step 1000: 0.792440
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.3%
# Minibatch loss at step 1100: 0.586728
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.2%
# Minibatch loss at step 1200: 1.154162
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.8%
# Minibatch loss at step 1300: 0.321618
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.9%
# Minibatch loss at step 1400: 0.466489
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.5%
# Minibatch loss at step 1500: 0.574570
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.1%
# Minibatch loss at step 1600: 0.844550
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.9%
# Minibatch loss at step 1700: 0.566282
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.6%
# Minibatch loss at step 1800: 0.628024
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.5%
# Minibatch loss at step 1900: 1.123282
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 2000: 0.102425
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.6%
# Test accuracy: 89.2%

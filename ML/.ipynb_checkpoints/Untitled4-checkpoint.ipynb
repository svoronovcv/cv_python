# %%
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5235, 3082, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'as', 'of', 'term', 'originated']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.131552
# Nearest to while: aragon, till, masamune, subdominant, reacting, metrodome, launch, weiser,
# Nearest to can: highlanders, romulus, skier, jebel, pseudoscientific, labia, caveats, mjd,
# Nearest to that: anglo, torrey, fanny, clearer, autopsy, hid, expandable, face,
# Nearest to at: arboreal, ic, glidrose, amstrad, troughton, formulate, cyg, lumi,
# Nearest to he: broader, scheer, intrinsic, sorcery, mechon, interrupting, kama, felicity,
# Nearest to after: diagnostic, haart, mansions, hu, drusilla, watertown, bahnhof, jurors,
# Nearest to had: distillers, unverifiable, creditor, disco, lettre, currently, prado, amass,
# Nearest to they: pear, reappearance, absence, cerro, nap, hacking, refusing, shy,
# Nearest to people: ecs, tat, tech, violates, scripted, rium, smallest, corporatist,
# Nearest to may: otherwise, demilitarized, crystalline, fin, celestine, fatalism, neely, ircii,
# Nearest to four: recited, parc, sweetheart, linemen, dative, nebula, appreciate, depatie,
# Nearest to has: duvall, episcopi, gazing, apache, stroustrup, jewry, acetyl, vla,
# Nearest to six: popularly, exponential, approximation, plough, anaerobic, supplementary, walt, provisionally,
# Nearest to states: females, haymarket, obligations, depictions, edvac, traitor, shapeshifting, vanir,
# Nearest to these: haircut, methadone, lian, comedies, archbishops, steffi, hor, shelved,
# Nearest to from: glorioso, ethnographic, norwegian, completely, wakefulness, obscured, divisors, architecturally,
# Average loss at step 2000: 4.360538
# Average loss at step 4000: 3.864964
# Average loss at step 6000: 3.787175
# Average loss at step 8000: 3.688388
# Average loss at step 10000: 3.612928
# Nearest to while: launch, masamune, galvani, when, xenakis, nessus, equites, standardize,
# Nearest to can: may, would, romulus, perils, vigor, pushed, could, coney,
# Nearest to that: which, differentiated, bayes, torrey, deshima, contractual, jogaila, lds,
# Nearest to at: on, edifices, in, ariosto, amstrad, fortunately, through, lundy,
# Nearest to he: it, they, who, she, there, hotspur, we, garz,
# Nearest to after: hu, during, diagnostic, nipple, drusilla, from, haart, of,
# Nearest to had: has, have, was, coincided, porsche, diskettes, been, activating,
# Nearest to they: he, not, who, it, there, we, hearsay, nap,
# Nearest to people: dhekelia, seydlitz, blind, violates, corporatist, smallest, pronounced, fathered,
# Nearest to may: can, would, might, borrelly, hormone, fin, tvs, biggest,
# Nearest to four: six, eight, three, five, seven, two, nine, zero,
# Nearest to has: had, is, was, have, constituci, nylon, salom, authoritarianism,
# Nearest to six: eight, four, seven, five, nine, three, zero, two,
# Nearest to states: haymarket, vanir, females, traitor, semipalatinsk, depictions, lusignan, obligations,
# Nearest to these: some, fateful, haircut, dialect, devine, roundel, procol, picts,
# Nearest to from: in, with, by, morel, into, of, after, foucault,
# Average loss at step 12000: 3.599054
# Average loss at step 14000: 3.573001
# Average loss at step 16000: 3.408457
# Average loss at step 18000: 3.457914
# Average loss at step 20000: 3.535899
# Nearest to while: when, weak, equites, although, masamune, demography, nessus, walther,
# Nearest to can: may, would, could, will, cannot, must, should, coney,
# Nearest to that: which, but, though, remain, actually, bargain, differentiated, when,
# Nearest to at: in, through, within, amstrad, edifices, on, under, importer,
# Nearest to he: it, they, she, who, there, garz, flannery, then,
# Nearest to after: before, during, from, when, at, millie, overrides, hu,
# Nearest to had: has, have, was, were, been, coincided, activating, ingest,
# Nearest to they: he, we, there, who, it, not, you, orcas,
# Nearest to people: seydlitz, years, blind, corporatist, violates, fathered, weighed, dhekelia,
# Nearest to may: can, would, might, could, cannot, must, should, will,
# Nearest to four: six, five, three, eight, seven, two, nine, zero,
# Nearest to has: had, was, is, have, cern, nylon, appliance, tripled,
# Nearest to six: five, seven, eight, four, three, nine, zero, two,
# Nearest to states: haymarket, vanir, traitor, lusignan, obligations, hallucinatory, females, django,
# Nearest to these: some, many, fateful, their, all, roundel, such, alcohols,
# Nearest to from: into, after, in, between, and, alternates, miyazaki, scrub,
# Average loss at step 22000: 3.501540
# Average loss at step 24000: 3.488201
# Average loss at step 26000: 3.478688
# Average loss at step 28000: 3.481945
# Average loss at step 30000: 3.501200
# Nearest to while: although, when, but, though, are, dwarves, before, walther,
# Nearest to can: may, would, could, will, must, cannot, should, might,
# Nearest to that: which, however, this, but, squads, torrey, jogaila, though,
# Nearest to at: in, edifices, under, outbound, mommsen, during, pellets, watered,
# Nearest to he: it, she, they, who, there, garz, we, flannery,
# Nearest to after: before, during, from, when, since, millie, dtd, hu,
# Nearest to had: has, have, was, were, is, ingest, montezuma, gave,
# Nearest to they: he, we, there, it, who, you, not, she,
# Nearest to people: years, seydlitz, blind, corporatist, weighed, violates, fathered, dhekelia,
# Nearest to may: can, would, might, must, could, will, should, cannot,
# Nearest to four: five, six, eight, seven, three, nine, two, zero,
# Nearest to has: had, have, is, was, cern, stooges, tripled, aleksei,
# Nearest to six: eight, four, five, nine, seven, three, zero, two,
# Nearest to states: haymarket, vanir, lusignan, kingdom, nanette, obligations, hallucinatory, hurry,
# Nearest to these: some, many, fateful, all, their, those, such, they,
# Nearest to from: into, after, under, in, through, between, by, within,
# Average loss at step 32000: 3.499614
# Average loss at step 34000: 3.491263
# Average loss at step 36000: 3.454875
# Average loss at step 38000: 3.302355
# Average loss at step 40000: 3.429327
# Nearest to while: although, when, though, but, before, where, ridgway, taboo,
# Nearest to can: may, will, could, would, must, should, cannot, might,
# Nearest to that: which, however, this, what, actually, but, deshima, because,
# Nearest to at: during, watered, usual, on, in, alarm, within, before,
# Nearest to he: she, it, they, who, there, garz, i, then,
# Nearest to after: before, during, from, since, when, millie, tak, at,
# Nearest to had: has, have, was, were, aac, stooges, knew, physiologic,
# Nearest to they: he, we, there, you, it, she, who, not,
# Nearest to people: blind, those, upkeep, seydlitz, comical, qe, wisc, men,
# Nearest to may: can, would, might, could, will, must, should, cannot,
# Nearest to four: six, five, seven, eight, three, two, nine, zero,
# Nearest to has: had, have, was, is, aac, since, tripled, stooges,
# Nearest to six: four, seven, five, eight, three, nine, zero, two,
# Nearest to states: kingdom, haymarket, ontario, lusignan, hurry, monosaccharide, vanir, obligations,
# Nearest to these: many, some, those, both, several, were, all, such,
# Nearest to from: into, through, in, after, with, for, between, mach,
# Average loss at step 42000: 3.432491
# Average loss at step 44000: 3.447218
# Average loss at step 46000: 3.449219
# Average loss at step 48000: 3.349049
# Average loss at step 50000: 3.386267
# Nearest to while: when, although, however, but, though, where, before, until,
# Nearest to can: may, would, will, could, must, should, cannot, might,
# Nearest to that: which, however, this, but, what, denies, where, jogaila,
# Nearest to at: usual, during, on, thrived, in, watered, importer, unhealthy,
# Nearest to he: she, it, they, who, there, flannery, garz, eventually,
# Nearest to after: before, during, when, from, while, since, through, until,
# Nearest to had: has, have, was, aac, were, having, knew, won,
# Nearest to they: we, he, there, you, it, she, these, terribly,
# Nearest to people: years, children, men, jews, players, blind, dhekelia, seydlitz,
# Nearest to may: can, would, will, could, should, might, must, cannot,
# Nearest to four: six, eight, five, seven, three, nine, zero, two,
# Nearest to has: had, have, is, was, aac, having, since, makes,
# Nearest to six: eight, seven, four, three, nine, five, zero, two,
# Nearest to states: kingdom, haymarket, obligations, ontario, hurry, forceful, nations, vanir,
# Nearest to these: some, many, both, those, such, several, they, fateful,
# Nearest to from: into, through, after, under, within, in, during, wala,
# Average loss at step 52000: 3.435617
# Average loss at step 54000: 3.423943
# Average loss at step 56000: 3.436071
# Average loss at step 58000: 3.390099
# Average loss at step 60000: 3.396611
# Nearest to while: although, when, before, after, though, boleyn, were, however,
# Nearest to can: may, would, could, will, must, should, cannot, might,
# Nearest to that: which, this, what, however, differentiated, denies, it, torrey,
# Nearest to at: in, procurement, during, unhealthy, carelessness, usual, watered, schaefer,
# Nearest to he: she, it, they, there, who, flannery, eventually, we,
# Nearest to after: before, during, when, while, through, since, without, until,
# Nearest to had: has, have, was, were, aac, knew, having, deco,
# Nearest to they: we, there, he, you, she, it, these, who,
# Nearest to people: players, jews, men, children, years, countries, those, comical,
# Nearest to may: can, would, will, must, could, should, might, cannot,
# Nearest to four: six, five, eight, seven, three, nine, zero, two,
# Nearest to has: had, have, was, is, aac, stooges, having, includes,
# Nearest to six: eight, four, five, nine, seven, three, zero, two,
# Nearest to states: kingdom, countries, nations, hurry, obligations, ontario, forceful, chalcedonian,
# Nearest to these: some, many, those, both, several, such, all, they,
# Nearest to from: into, through, within, between, after, under, outstripped, wala,
# Average loss at step 62000: 3.241492
# Average loss at step 64000: 3.253895
# Average loss at step 66000: 3.398368
# Average loss at step 68000: 3.393152
# Average loss at step 70000: 3.359816
# Nearest to while: although, when, however, and, though, before, boleyn, wireless,
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to that: which, however, what, but, actually, this, differentiated, usually,
# Nearest to at: in, monophonic, unhealthy, during, within, ariosto, watered, edifices,
# Nearest to he: she, it, they, there, flannery, then, who, eventually,
# Nearest to after: before, during, when, through, while, until, without, passers,
# Nearest to had: have, has, was, were, deco, having, been, aac,
# Nearest to they: we, he, there, you, she, it, then, vaishnavism,
# Nearest to people: players, men, children, countries, writers, jews, others, things,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to four: six, five, eight, seven, three, zero, nine, two,
# Nearest to has: had, have, was, is, stooges, includes, since, aac,
# Nearest to six: eight, four, seven, five, nine, three, zero, two,
# Nearest to states: kingdom, nations, obligations, countries, state, hurry, haymarket, ontario,
# Nearest to these: some, such, many, are, those, the, all, which,
# Nearest to from: through, into, within, between, in, during, nice, bundeswehr,
# Average loss at step 72000: 3.371764
# Average loss at step 74000: 3.350315
# Average loss at step 76000: 3.316576
# Average loss at step 78000: 3.349507
# Average loss at step 80000: 3.373701
# Nearest to while: although, when, though, however, but, before, after, or,
# Nearest to can: may, could, will, would, should, cannot, must, might,
# Nearest to that: which, however, this, generally, usually, actually, courted, where,
# Nearest to at: in, during, from, edifices, within, under, on, before,
# Nearest to he: she, it, they, there, flannery, who, we, garz,
# Nearest to after: before, during, when, while, without, until, through, despite,
# Nearest to had: have, has, were, was, deco, having, rostock, began,
# Nearest to they: we, he, there, you, she, it, shimei, who,
# Nearest to people: children, men, players, countries, someone, things, peoples, jews,
# Nearest to may: can, could, will, must, might, would, should, cannot,
# Nearest to four: five, six, seven, eight, three, nine, zero, two,
# Nearest to has: had, have, is, was, stooges, includes, since, having,
# Nearest to six: four, eight, five, seven, nine, three, zero, two,
# Nearest to states: kingdom, nations, state, obligations, hurry, countries, haymarket, ontario,
# Nearest to these: many, several, those, some, such, both, various, are,
# Nearest to from: through, into, within, under, outstripped, in, after, during,
# Average loss at step 82000: 3.407910
# Average loss at step 84000: 3.410785
# Average loss at step 86000: 3.385234
# Average loss at step 88000: 3.352515
# Average loss at step 90000: 3.362853
# Nearest to while: although, when, though, and, before, after, but, during,
# Nearest to can: could, may, will, should, must, would, might, cannot,
# Nearest to that: which, however, torrey, what, but, workshops, oliphant, denies,
# Nearest to at: during, on, under, watered, mommsen, ariosto, near, throughout,
# Nearest to he: she, they, it, there, who, flannery, later, garz,
# Nearest to after: before, during, when, until, despite, while, without, through,
# Nearest to had: has, have, was, were, having, began, knew, deco,
# Nearest to they: we, he, there, she, you, it, who, cohorts,
# Nearest to people: children, men, players, students, jews, women, countries, person,
# Nearest to may: can, could, must, would, will, should, might, cannot,
# Nearest to four: seven, five, eight, three, six, nine, two, zero,
# Nearest to has: had, have, is, having, was, includes, since, makes,
# Nearest to six: seven, eight, five, four, nine, three, zero, two,
# Nearest to states: kingdom, nations, obligations, state, hurry, haymarket, ontario, lusignan,
# Nearest to these: many, some, several, those, such, are, various, both,
# Nearest to from: through, into, during, under, between, within, before, after,
# Average loss at step 92000: 3.400034
# Average loss at step 94000: 3.243563
# Average loss at step 96000: 3.355779
# Average loss at step 98000: 3.240966
# Average loss at step 100000: 3.352025
# Nearest to while: although, when, though, and, after, where, before, but,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to that: which, however, what, denies, kaleidoscope, torrey, wedded, actually,
# Nearest to at: during, in, within, strangelove, after, on, ariosto, procurement,
# Nearest to he: she, they, it, there, we, who, eventually, garz,
# Nearest to after: before, during, when, without, despite, while, until, through,
# Nearest to had: has, have, was, were, having, would, is, zo,
# Nearest to they: we, he, there, you, she, it, i, these,
# Nearest to people: children, players, men, jews, countries, students, things, women,
# Nearest to may: can, could, must, should, might, would, will, cannot,
# Nearest to four: seven, six, eight, five, three, nine, zero, two,
# Nearest to has: had, have, is, was, stooges, since, having, includes,
# Nearest to six: seven, eight, four, five, nine, three, zero, two,
# Nearest to states: kingdom, nations, obligations, state, countries, haymarket, ontario, cuc,
# Nearest to these: several, some, many, those, various, such, all, certain,
# Nearest to from: through, into, in, within, under, bundeswehr, nicolau, between,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
